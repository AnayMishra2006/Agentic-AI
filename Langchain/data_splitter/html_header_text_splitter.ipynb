# %%
from langchain_text_splitters import HTMLHeaderTextSplitter

html_string = """<!DOCTYPE html>
<html>
<body>
<h1>Hello World From HTML</h1>

<h2>Hi There</h2>
</body>
</html>
"""

headers_to_split_on = [
    ("h1", "Header 1"),
    ("h2", "Header 2"),
    ("h3", "Header 3"),
]

html_splitter = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)

html_header_split = html_splitter.split_text(html_string)
html_header_split
# Out:
# [Document(metadata={'Header 1': 'Hello World From HTML'}, page_content='Hello World From HTML'),
#  Document(metadata={'Header 1': 'Hello World From HTML', 'Header 2': 'Hi There'}, page_content='Hi There')]

# %%
url="https://docs.langchain.com/oss/python/langchain/overview"

headers_to_split_on=[
    ("h1","Header 1"),
    ("h2","Header 2"),
    ("h3","Header 3")
]
html_splitter=HTMLHeaderTextSplitter(headers_to_split_on)
html_header_split=html_splitter.split_text_from_url(url)
html_header_split
# Out:
# [Document(metadata={}, page_content='$ /$  \n((a,b,c,d,e,f,g,h)=>{let i=document.documentElement,j=["light","dark"];function k(b){var c;(Array.isArray(a)?a:[a]).forEach(a=>{let c="class"===a,d=c&&f?e.map(a=>f[a]||a):e;c?(i.classList.remove(...d),i.classList.add(f&&f[b]?f[b]:b)):i.setAttribute(a,b)}),c=b,h&&j.includes(c)&&(i.style.colorScheme=c)}if(d)k(d);else try{let a=localStorage.getItem(b)||c,d=g&&"system"===a?window.matchMedia("(prefers-color-scheme: dark)").matches?"dark":"light":a;k(d)}catch(a){}})("class","isDarkMode","system",null,["dark","light","true","false","system"],{"true":"dark","false":"light","dark":"dark","light":"light"},true,true)  \n(self.__next_s=self.__next_s||[]).push([0,{"children":"(function m(a,b,c,d){try{let e=document.getElementById(\\"banner\\"),f=e?.innerText;if(!f)return void document.documentElement.setAttribute(d,\\"hidden\\");let g=localStorage.getItem(a),h=g!==f&&g!==b;null!=g&&(h?(localStorage.removeItem(c),localStorage.removeItem(a)):(localStorage.setItem(c,b),localStorage.setItem(a,b))),document.documentElement.setAttribute(d,!g||h?\\"visible\\":\\"hidden\\")}catch(a){console.error(a),document.documentElement.setAttribute(d,\\"hidden\\")}})(\\n  \\"langchain-5e9cc07a-bannerDismissed\\",\\n  undefined,\\n  \\"__mintlify-bannerDismissed\\",\\n  \\"data-banner-state\\",\\n)","id":"_mintlify-banner-script"}])  \n:root {\n  --font-family-headings-custom: "Manrope", -apple-system, BlinkMacSystemFont, "Segoe UI", system-ui, sans-serif;\n  \n  \n  \n}  \n:root {\n    --primary: 47 104 104;\n    --primary-light: 132 196 192;\n    --primary-dark: 28 60 60;\n    --tooltip-foreground: 255 255 255;\n    --background-light: 255 255 255;\n    --background-dark: 11 13 15;\n    --gray-50: 244 246 246;\n    --gray-100: 239 241 241;\n    --gray-200: 223 225 225;\n    --gray-300: 207 209 209;\n    --gray-400: 159 161 161;\n    --gray-500: 113 115 115;\n    --gray-600: 81 83 83;\n    --gray-700: 63 65 65;\n    --gray-800: 38 40 40;\n    --gray-900: 24 25 25;\n    --gray-950: 11 13 13;\n  }  \n(function() {\n            function loadKatex() {\n              const link = document.querySelector(\'link[href="https://d4tuoctqmanu0.cloudfront.net/katex.min.css"]\');\n              if (link) link.rel = \'stylesheet\';\n            }\n            if (document.readyState === \'loading\') {\n              document.addEventListener(\'DOMContentLoaded\', loadKatex);\n            } else {\n              loadKatex();\n            }\n          })();  \n(self.__next_s=self.__next_s||[]).push([0,{"suppressHydrationWarning":true,"children":"(function(a,b,c,d){var e;let f,g=\\"mint\\"===d||\\"linden\\"===d?\\"sidebar\\":\\"sidebar-content\\",h=(e=d,f=\\"navbar-transition\\",\\"maple\\"===e&&(f+=\\"-maple\\"),\\"willow\\"===e&&(f+=\\"-willow\\"),f);function i(){document.documentElement.classList.add(\\"lg:[--scroll-mt:9.5rem]\\")}function j(a){document.getElementById(g)?.style.setProperty(\\"top\\",`${a}rem`)}function k(a){document.getElementById(g)?.style.setProperty(\\"height\\",`calc(100vh - ${a}rem)`)}function l(a,b){!a&&b||a&&!b?(i(),document.documentElement.classList.remove(\\"lg:[--scroll-mt:12rem]\\")):a&&b&&(document.documentElement.classList.add(\\"lg:[--scroll-mt:12rem]\\"),document.documentElement.classList.remove(\\"lg:[--scroll-mt:9.5rem]\\"))}let m=document.documentElement.getAttribute(\\"data-banner-state\\"),n=null!=m?\\"visible\\"===m:b;switch(d){case\\"mint\\":j(c),l(a,n);break;case\\"palm\\":case\\"aspen\\":j(c),k(c),l(a,n);break;case\\"linden\\":j(c),n&&i();break;case\\"almond\\":document.documentElement.style.setProperty(\\"--scroll-mt\\",\\"2.5rem\\"),j(c),k(c)}let o=function(){let a=document.createElement(\\"style\\");return a.appendChild(document.createTextNode(\\"*,*::before,*::after{-webkit-transition:none!important;-moz-transition:none!important;-o-transition:none!important;-ms-transition:none!important;transition:none!important}\\")),document.head.appendChild(a),function(){window.getComputedStyle(doc ...
#  Document(metadata={'Header 1': 'LangChain overview'}, page_content='LangChain overview'),
#  Document(metadata={}, page_content='Copy page  \nLangChain is an open source framework with a pre-built agent architecture and integrations for any model or tool — so you can build agents that adapt as fast as the ecosystem evolves  \nCopy page  \nLangChain is the easiest way to start building agents and applications powered by LLMs. With under 10 lines of code, you can connect to OpenAI, Anthropic, Google, and . LangChain provides a pre-built agent architecture and model integrations to help you get started quickly and seamlessly incorporate LLMs into your agents and applications.  \nmore  \nWe recommend you use LangChain if you want to quickly build agents and autonomous applications. Use , our low-level agent orchestration framework and runtime, when you have more advanced needs that require a combination of deterministic and agentic workflows, heavy customization, and carefully controlled latency.  \nLangGraph  \nLangChain are built on top of LangGraph in order to provide durable execution, streaming, human-in-the-loop, persistence, and more. You do not need to know LangGraph for basic LangChain agent usage.  \nagents  \n\u200b  \nCreate an agent  \nCopy  \n# pip install -qU langchain "langchain[anthropic]"  \nfrom  \nlangchain.agents  \nimport  \ncreate_agent  \ndef  \nget_weather  \n(  \ncity  \n:  \nstr  \n) ->  \nstr  \n:  \n"""Get weather for a given city."""  \nreturn  \nf  \n"It\'s always sunny in  \n{  \ncity  \n}  \n!"  \nagent  \n=  \ncreate_agent(  \nmodel  \n=  \n"claude-sonnet-4-5-20250929"  \n,  \ntools  \n=  \n[get_weather],  \nsystem_prompt  \n=  \n"You are a helpful assistant"  \n,  \n)  \n# Run the agent  \nagent.invoke(  \n{  \n"messages"  \n: [{  \n"role"  \n:  \n"user"  \n,  \n"content"  \n:  \n"what is the weather in sf"  \n}]}  \n)  \nSee the and to get started building your own agents and applications with LangChain.  \nInstallation instructions  \nQuickstart guide  \n\u200b  \nCore benefits'),
#  Document(metadata={'Header 2': 'Standard model interface'}, page_content='Standard model interface'),
#  Document(metadata={'Header 2': 'Standard model interface'}, page_content='Different providers have unique APIs for interacting with models, including the format of responses. LangChain standardizes how you interact with models so that you can seamlessly swap providers and avoid lock-in.  \nLearn more'),
#  Document(metadata={'Header 2': 'Easy to use, highly flexible agent'}, page_content='Easy to use, highly flexible agent'),
#  Document(metadata={'Header 2': 'Easy to use, highly flexible agent'}, page_content='LangChain’s agent abstraction is designed to be easy to get started with, letting you build a simple agent in under 10 lines of code. But it also provides enough flexibility to allow you to do all the context engineering your heart desires.  \nLearn more'),
#  Document(metadata={'Header 2': 'Built on top of LangGraph'}, page_content='Built on top of LangGraph'),
#  Document(metadata={'Header 2': 'Built on top of LangGraph'}, page_content='LangChain’s agents are built on top of LangGraph. This allows us to take advantage of LangGraph’s durable execution, human-in-the-loop support, persistence, and more.  \nLearn more'),
#  Document(metadata={'Header 2': 'Debug with LangSmith'}, page_content='Debug with LangSmith'),
#  Document(metadata={}, page_content='Gain deep visibility into complex agent behavior with visualization tools that trace execution paths, capture state transitions, and provide detailed runtime metrics.  \nLearn more  \nor .  \nEdit this page on GitHub  \nfile an issue  \nto Claude, VSCode, and more via MCP for real-time answers.  \nConnect these docs  \nWas this page helpful?  \nYes  \nNo  \nInstall LangChain  \nNext  \n⌘ I  \nDocs by LangChain home page  \ngithub  \nx  \nlinkedin  \nyoutube  \nResources  \nForum  \nChangelog  \nLangChain Academy  \nTrust Center  \nCompany  \nAbout  \nCareers  \nBlog  \ngithub  \nx  \nlinkedin  \nyoutube  \nPowered by  \n(self.__next_f=self.__next_f||[]).push([0])  \nself.__next_f.push([1,"1:\\"$Sreact.fragment\\"\\n2:I[85341,[],\\"\\"]\\n"])  \nself.__next_f.push([1,"3:I[2510,[\\"73473\\",\\"static/chunks/891cff7f-dcf0b8e94fd9e2cd.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"82431\\",\\"static/chunks/82431-0fdd05cdeb508131.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"85200\\",\\"static/chunks/85200-6eba77a80319542a.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"90942\\",\\"static/chunks/90942-e53f308bf0b25715.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"98816\\",\\"static/chunks/98816-4875194b6205382d.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"94393\\",\\"static/chunks/94393-6b70c220d3a90899.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"19664\\",\\"static/chunks/19664-8ce43df6b74bea12.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"21581\\",\\"static/chunks/21581-66298733a76ffbc8.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"48170\\",\\"static/chunks/48170-8767898ea43cea00.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"30479\\",\\"static/chunks/30479-c09b16d087997b35.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"18039\\",\\"static/chunks/app/error-92f54a0b03b3dca5.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\"],\\"default\\",1]\\n"])  \nself.__next_f.push([1,"4:I[90025,[],\\"\\"]\\n"])  \nself.__next_f.push([1,"5:I[51749,[\\"73473\\",\\"static/chunks/891cff7f-dcf0b8e94fd9e2cd.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"53016\\",\\"static/chunks/cfdfcc00-442051842d4b5e4f.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"41725\\",\\"static/chunks/d30757c7-2d2105da33b688d0.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"82431\\",\\"static/chunks/82431-0fdd05cdeb508131.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"85200\\",\\"static/chunks/85200-6eba77a80319542a.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"90942\\",\\"static/chunks/90942-e53f308bf0b25715.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"98816\\",\\"static/chunks/98816-4875194b6205382d.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"94393\\",\\"static/chunks/94393-6b70c220d3a90899.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"19664\\",\\"static/chunks/19664-8ce43df6b74bea12.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"21581\\",\\"static/chunks/21581-66298733a76ffbc8.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"43408\\",\\"static/chunks/43408-887fc11abc516fe9.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"42414\\",\\"static/chunks/42414-bee4c82c54642c68.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"58029\\",\\"static/chunks/58029-7040f88549a5678b.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"20560\\",\\"static/chunks/20560-6602de765fecea3f.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"38009\\",\\"static/chunks/38009-a352246cfb0cbe83.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"31601\\",\\"static/chunks/31601-0cc5786e6147aed4.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"48170\\",\\"static/chunks/48170-8767898ea43cea00.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"50077\\",\\"static/chunks/50077-27cb93ade3de2ea7.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"17610\\",\\"static/chunks/17610-3c1a1af35076fe6d.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"73008\\",\\"static/chunks/73008-7413b81e788745b3.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"57735\\",\\"static/chunks/57735-4f800af818b7009f.js?dpl=dpl_DthYoWAHBNXQQgrsL8rNHKJHCa4x\\",\\"10 ...
